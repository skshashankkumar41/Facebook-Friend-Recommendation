# %% [markdown]
# <p style="font-size:32px;text-align:center"> <b>Social network Graph Link Prediction - Facebook Challenge</b> </p>

# %%
#Importing Libraries
# please do go through this python notebook: 
import warnings
warnings.filterwarnings("ignore")

import csv
import pandas as pd#pandas to create small dataframes 
import datetime #Convert to unix time
import time #Convert to unix time
# if numpy is not installed already : pip3 install numpy
import numpy as np#Do aritmetic operations on arrays
# matplotlib: used to plot graphs
import matplotlib
import matplotlib.pylab as plt
import seaborn as sns#Plots
from matplotlib import rcParams#Size of plots  
from sklearn.cluster import MiniBatchKMeans, KMeans#Clustering
import math
import pickle
import os
# to install xgboost: pip3 install xgboost
import xgboost as xgb

import warnings
import networkx as nx
import pdb
import pickle
from pandas import HDFStore,DataFrame
from pandas import read_hdf
from scipy.sparse.linalg import svds, eigs
import gc
from tqdm import tqdm
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %%
#reading
from pandas import read_hdf
df_final_train = read_hdf('data/fea_sample/storage_sample_stage4.h5', 'train_df',mode='r')
df_final_test = read_hdf('data/fea_sample/storage_sample_stage4.h5', 'test_df',mode='r')

# %%
df_final_train.columns
# Out:
# Index(['source_node', 'destination_node', 'indicator_link',
#        'jaccard_followers', 'jaccard_followees', 'cosine_followers',
#        'cosine_followees', 'num_followers_s', 'num_followers_d',
#        'num_followees_s', 'num_followees_d', 'inter_followers',
#        'inter_followees', 'adar_index', 'follows_back', 'same_comp',
#        'shortest_path', 'weight_in', 'weight_out', 'weight_f1', 'weight_f2',
#        'weight_f3', 'weight_f4', 'page_rank_s', 'page_rank_d', 'katz_s',
#        'katz_d', 'hubs_s', 'hubs_d', 'authorities_s', 'authorities_d',
#        'svd_u_s_1', 'svd_u_s_2', 'svd_u_s_3', 'svd_u_s_4', 'svd_u_s_5',
#        'svd_u_s_6', 'svd_u_d_1', 'svd_u_d_2', 'svd_u_d_3', 'svd_u_d_4',
#        'svd_u_d_5', 'svd_u_d_6', 'svd_v_s_1', 'svd_v_s_2', 'svd_v_s_3',
#        'svd_v_s_4', 'svd_v_s_5', 'svd_v_s_6', 'svd_v_d_1', 'svd_v_d_2',
#        'svd_v_d_3', 'svd_v_d_4', 'svd_v_d_5', 'svd_v_d_6'],
#       dtype='object')

# %%
y_train = df_final_train.indicator_link
y_test = df_final_test.indicator_link

# %%
df_final_train.drop(['source_node', 'destination_node','indicator_link'],axis=1,inplace=True)
df_final_test.drop(['source_node', 'destination_node','indicator_link'],axis=1,inplace=True)

# %%
estimators = [10,50,100,250,450]
train_scores = []
test_scores = []
for i in estimators:
    clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=5, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=52, min_samples_split=120,
            min_weight_fraction_leaf=0.0, n_estimators=i, n_jobs=-1,random_state=25,verbose=0,warm_start=False)
    clf.fit(df_final_train,y_train)
    train_sc = f1_score(y_train,clf.predict(df_final_train))
    test_sc = f1_score(y_test,clf.predict(df_final_test))
    test_scores.append(test_sc)
    train_scores.append(train_sc)
    print('Estimators = ',i,'Train Score',train_sc,'test Score',test_sc)
plt.plot(estimators,train_scores,label='Train Score')
plt.plot(estimators,test_scores,label='Test Score')
plt.xlabel('Estimators')
plt.ylabel('Score')
plt.title('Estimators vs score at depth of 5')
# Out:
# Estimators =  10 Train Score 0.919328436516 test Score 0.880048826209
# Estimators =  50 Train Score 0.925598885502 test Score 0.901259737751
# Estimators =  100 Train Score 0.926159009859 test Score 0.921724094302
# Estimators =  250 Train Score 0.924602259626 test Score 0.921053186331
# Estimators =  450 Train Score 0.92499737973 test Score 0.921409899654
# Text(0.5,1,'Estimators vs score at depth of 5')

# %%
depths = [3,9,11,15,20,35,50,70,130]
train_scores = []
test_scores = []
for i in depths:
    clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=i, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=52, min_samples_split=120,
            min_weight_fraction_leaf=0.0, n_estimators=115, n_jobs=-1,random_state=25,verbose=0,warm_start=False)
    clf.fit(df_final_train,y_train)
    train_sc = f1_score(y_train,clf.predict(df_final_train))
    test_sc = f1_score(y_test,clf.predict(df_final_test))
    test_scores.append(test_sc)
    train_scores.append(train_sc)
    print('depth = ',i,'Train Score',train_sc,'test Score',test_sc)
plt.plot(depths,train_scores,label='Train Score')
plt.plot(depths,test_scores,label='Test Score')
plt.xlabel('Depth')
plt.ylabel('Score')
plt.title('Depth vs score at depth of 5 at estimators = 115')
plt.show()
# Out:
# depth =  3 Train Score 0.889166314008 test Score 0.866057509094
# depth =  9 Train Score 0.954336449938 test Score 0.924656379121
# depth =  11 Train Score 0.961777669201 test Score 0.926526054068
# depth =  15 Train Score 0.964247240798 test Score 0.926852905237
# depth =  20 Train Score 0.965591441505 test Score 0.927756493917
# depth =  35 Train Score 0.965745430187 test Score 0.92796396093
# depth =  50 Train Score 0.965745430187 test Score 0.92796396093
# depth =  70 Train Score 0.965745430187 test Score 0.92796396093
# depth =  130 Train Score 0.965745430187 test Score 0.92796396093

# %%
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform

param_dist = {"n_estimators":sp_randint(105,125),
              "max_depth": sp_randint(10,15),
              "min_samples_split": sp_randint(110,190),
              "min_samples_leaf": sp_randint(25,65)}

clf = RandomForestClassifier(random_state=25,n_jobs=-1)

rf_random = RandomizedSearchCV(clf, param_distributions=param_dist,
                                   n_iter=5,cv=10,scoring='f1',random_state=25)

rf_random.fit(df_final_train,y_train)
print('mean test scores',rf_random.cv_results_['mean_test_score'])
# Out:
# mean test scores [ 0.96299194  0.96282221  0.96104384  0.96223757  0.96472421]

# %%
print(rf_random.best_estimator_)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=14, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=28, min_samples_split=111,
#                        min_weight_fraction_leaf=0.0, n_estimators=121,
#                        n_jobs=-1, oob_score=False, random_state=25, verbose=0,
#                        warm_start=False)

# %%
clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=14, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=28, min_samples_split=111,
            min_weight_fraction_leaf=0.0, n_estimators=121, n_jobs=-1,
            oob_score=False, random_state=25, verbose=0, warm_start=False)

# %%
clf.fit(df_final_train,y_train)
y_train_pred = clf.predict(df_final_train)
y_test_pred = clf.predict(df_final_test)

# %%
from sklearn.metrics import f1_score
print('Train f1 score',f1_score(y_train,y_train_pred))
print('Test f1 score',f1_score(y_test,y_test_pred))
# Out:
# Train f1 score 0.966912958753
# Test f1 score 0.928314128626

# %%
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    
    A =(((C.T)/(C.sum(axis=1))).T)
    
    B =(C/C.sum(axis=0))
    plt.figure(figsize=(20,4))
    
    labels = [0,1]
    # representing A in heatmap format
    cmap=sns.light_palette("blue")
    plt.subplot(1, 3, 1)
    sns.heatmap(C, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Confusion matrix")
    
    plt.subplot(1, 3, 2)
    sns.heatmap(B, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Precision matrix")
    
    plt.subplot(1, 3, 3)
    # representing B in heatmap format
    sns.heatmap(A, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Recall matrix")
    
    plt.show()

# %%
print('Train confusion_matrix')
plot_confusion_matrix(y_train,y_train_pred)
print('Test confusion_matrix')
plot_confusion_matrix(y_test,y_test_pred)
# Out:
# Train confusion_matrix
# Test confusion_matrix

# %%
from sklearn.metrics import roc_curve, auc
fpr,tpr,ths = roc_curve(y_test,y_test_pred)
auc_sc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='navy',label='ROC curve (area = %0.2f)' % auc_sc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic with test data')
plt.legend()
plt.show()

# %%
features = df_final_train.columns
importances = clf.feature_importances_
indices = (np.argsort(importances))[-25:]
plt.figure(figsize=(10,12))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='r', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# # Preferential Attachment Feature

# %%
df_final_train.head()
# Out:
#    jaccard_followers  jaccard_followees  cosine_followers  cosine_followees  \
# 0                  0           0.000000          0.000000          0.000000
# 1                  0           0.407407          0.169548          0.582182
# 2                  0           0.187500          0.134164          0.327327
# 3                  0           0.000000          0.000000          0.000000
# 4                  0           0.000000          0.050252          0.000000
#
#    num_followers_s  num_followers_d  num_followees_s  num_followees_d  \
# 0               11                6               15                8
# 1               29               23               21               17
# 2                5               10                7               12
# 3                8               13               15               24
# 4               11                6               12                6
#
#    inter_followers  inter_followees      ...          svd_v_s_3     svd_v_s_4  \
# 0                0                0      ...       1.983705e-06  1.545077e-13
# 1               21               11      ...       7.757241e-20 -2.357495e-19
# 2                3                3      ...       3.989004e-11  6.951261e-14
# 3                0                0      ...       3.460528e-10  2.437044e-13
# 4                1                0      ...       1.390613e-12  9.647552e-12
#
#       svd_v_s_5     svd_v_s_6     svd_v_d_1     svd_v_d_2     svd_v_d_3  \
# 0  8.108427e-13  1.719701e-14 -1.355366e-12  4.675306e-13  1.128588e-06
# 1 -1.603849e-19  5.689671e-21  1.274447e-19 -6.288189e-20  5.755000e-20
# 2  2.528174e-14  4.889795e-14 -1.195007e-12  3.169914e-13  9.242597e-11
# 3  1.788353e-12  1.488907e-15 -1.645821e-12  1.690582e-11  1.947851e-10
# 4  2.353031e-09  5.623551e-15 -5.094863e-13  6.828593e-13  8.249436e-13
#
#       svd_v_d_4     svd_v_d_5     svd_v_d_6
# 0  6.616654e-14  9.771068e-13  4.160009e-14
# 1 -2.025439e-19 -1.265326e-19  2.334478e-21
# 2  1.221675e-12  2.639144e-11  1.016047e-13
# 3  7.582002e-12  1.077090e-11  5.139933e-14
# 4  1.336026e-12  2.078939e-09  7.827372e-16
#
# [5 rows x 52 columns]

# %%
df_final_train['preferential_attachment']=(df_final_train.num_followers_s+df_final_train.num_followees_s)*(df_final_train.num_followers_d+df_final_train.num_followees_d)

# %%
df_final_test['preferential_attachment']=(df_final_test.num_followers_s+df_final_test.num_followees_s)*(df_final_test.num_followers_d+df_final_test.num_followees_d)

# %%
df_final_train.head()
# Out:
#    jaccard_followers  jaccard_followees  cosine_followers  cosine_followees  \
# 0                  0           0.000000          0.000000          0.000000
# 1                  0           0.407407          0.169548          0.582182
# 2                  0           0.187500          0.134164          0.327327
# 3                  0           0.000000          0.000000          0.000000
# 4                  0           0.000000          0.050252          0.000000
#
#    num_followers_s  num_followers_d  num_followees_s  num_followees_d  \
# 0               11                6               15                8
# 1               29               23               21               17
# 2                5               10                7               12
# 3                8               13               15               24
# 4               11                6               12                6
#
#    inter_followers  inter_followees           ...                svd_v_s_4  \
# 0                0                0           ...             1.545077e-13
# 1               21               11           ...            -2.357495e-19
# 2                3                3           ...             6.951261e-14
# 3                0                0           ...             2.437044e-13
# 4                1                0           ...             9.647552e-12
#
#       svd_v_s_5     svd_v_s_6     svd_v_d_1     svd_v_d_2     svd_v_d_3  \
# 0  8.108427e-13  1.719701e-14 -1.355366e-12  4.675306e-13  1.128588e-06
# 1 -1.603849e-19  5.689671e-21  1.274447e-19 -6.288189e-20  5.755000e-20
# 2  2.528174e-14  4.889795e-14 -1.195007e-12  3.169914e-13  9.242597e-11
# 3  1.788353e-12  1.488907e-15 -1.645821e-12  1.690582e-11  1.947851e-10
# 4  2.353031e-09  5.623551e-15 -5.094863e-13  6.828593e-13  8.249436e-13
#
#       svd_v_d_4     svd_v_d_5     svd_v_d_6  preferential_attachment
# 0  6.616654e-14  9.771068e-13  4.160009e-14                      364
# 1 -2.025439e-19 -1.265326e-19  2.334478e-21                     2000
# 2  1.221675e-12  2.639144e-11  1.016047e-13                      264
# 3  7.582002e-12  1.077090e-11  5.139933e-14                      851
# 4  1.336026e-12  2.078939e-09  7.827372e-16                      276
#
# [5 rows x 53 columns]

# %% [markdown]
# # SVD Dot Feature

# %%
df_final_train.columns
# Out:
# Index(['jaccard_followers', 'jaccard_followees', 'cosine_followers',
#        'cosine_followees', 'num_followers_s', 'num_followers_d',
#        'num_followees_s', 'num_followees_d', 'inter_followers',
#        'inter_followees', 'adar_index', 'follows_back', 'same_comp',
#        'shortest_path', 'weight_in', 'weight_out', 'weight_f1', 'weight_f2',
#        'weight_f3', 'weight_f4', 'page_rank_s', 'page_rank_d', 'katz_s',
#        'katz_d', 'hubs_s', 'hubs_d', 'authorities_s', 'authorities_d',
#        'svd_u_s_1', 'svd_u_s_2', 'svd_u_s_3', 'svd_u_s_4', 'svd_u_s_5',
#        'svd_u_s_6', 'svd_u_d_1', 'svd_u_d_2', 'svd_u_d_3', 'svd_u_d_4',
#        'svd_u_d_5', 'svd_u_d_6', 'svd_v_s_1', 'svd_v_s_2', 'svd_v_s_3',
#        'svd_v_s_4', 'svd_v_s_5', 'svd_v_s_6', 'svd_v_d_1', 'svd_v_d_2',
#        'svd_v_d_3', 'svd_v_d_4', 'svd_v_d_5', 'svd_v_d_6'],
#       dtype='object')

# %%
df_source_u=df_final_train[['svd_u_s_1', 'svd_u_s_2', 'svd_u_s_3', 'svd_u_s_4', 'svd_u_s_5',
       'svd_u_s_6']]
df_source_v=df_final_train[['svd_v_s_1', 'svd_v_s_2', 'svd_v_s_3',
       'svd_v_s_4', 'svd_v_s_5', 'svd_v_s_6']]

# %%
df_source_u.head()
# Out:
#       svd_u_s_1     svd_u_s_2     svd_u_s_3     svd_u_s_4     svd_u_s_5  \
# 0 -1.666258e-13  4.613784e-13  1.043043e-05  6.677967e-13  2.451101e-13
# 1  5.215662e-19 -3.950777e-19  2.263040e-19 -9.935141e-19 -8.372973e-19
# 2 -2.763667e-14  1.546711e-14  7.794755e-11  1.224210e-13  2.867995e-13
# 3 -3.739767e-13  2.132016e-11  3.582238e-09  6.835542e-13  6.151620e-12
# 4 -8.389982e-14  1.167960e-11  2.562356e-12  4.164955e-13  3.833107e-11
#
#       svd_u_s_6
# 0  3.584945e-12
# 1 -3.036075e-21
# 2  2.510558e-15
# 3  3.518049e-15
# 4  2.272218e-15

# %%
df_source_v.head()
# Out:
#       svd_v_s_1     svd_v_s_2     svd_v_s_3     svd_v_s_4     svd_v_s_5  \
# 0 -7.216117e-13  3.926247e-13  1.983705e-06  1.545077e-13  8.108427e-13
# 1  1.721304e-19 -5.929097e-20  7.757241e-20 -2.357495e-19 -1.603849e-19
# 2 -9.249318e-14  5.366890e-15  3.989004e-11  6.951261e-14  2.528174e-14
# 3 -9.924795e-13  3.509177e-12  3.460528e-10  2.437044e-13  1.788353e-12
# 4 -3.988534e-13  1.119933e-12  1.390613e-12  9.647552e-12  2.353031e-09
#
#       svd_v_s_6
# 0  1.719701e-14
# 1  5.689671e-21
# 2  4.889795e-14
# 3  1.488907e-15
# 4  5.623551e-15

# %%
df_destination_u=df_final_train[['svd_u_d_1', 'svd_u_d_2', 'svd_u_d_3', 'svd_u_d_4',
       'svd_u_d_5', 'svd_u_d_6']]
df_destination_v=df_final_train[['svd_v_d_1', 'svd_v_d_2',
       'svd_v_d_3', 'svd_v_d_4', 'svd_v_d_5', 'svd_v_d_6']]

# %%
df_destination_u.head()
# Out:
#       svd_u_d_1     svd_u_d_2     svd_u_d_3     svd_u_d_4     svd_u_d_5  \
# 0 -2.038017e-11  5.397877e-13  1.068944e-06  1.192454e-12  2.279485e-12
# 1  4.050035e-19 -4.543848e-19  1.775320e-19 -8.375139e-19 -6.880291e-19
# 2 -9.009384e-12  2.812409e-12  6.959262e-10  1.607962e-10  5.961792e-12
# 3 -2.088991e-11  6.903177e-11  2.692168e-10  8.063429e-12  2.359907e-11
# 4 -4.679923e-14  1.000212e-11  5.831231e-13  1.981892e-13  1.918718e-11
#
#       svd_u_d_6
# 0  3.581202e-12
# 1  3.535905e-20
# 2  1.400334e-13
# 3  6.084473e-15
# 4  8.503123e-16

# %%
df_destination_v.head()
# Out:
#       svd_v_d_1     svd_v_d_2     svd_v_d_3     svd_v_d_4     svd_v_d_5  \
# 0 -1.355366e-12  4.675306e-13  1.128588e-06  6.616654e-14  9.771068e-13
# 1  1.274447e-19 -6.288189e-20  5.755000e-20 -2.025439e-19 -1.265326e-19
# 2 -1.195007e-12  3.169914e-13  9.242597e-11  1.221675e-12  2.639144e-11
# 3 -1.645821e-12  1.690582e-11  1.947851e-10  7.582002e-12  1.077090e-11
# 4 -5.094863e-13  6.828593e-13  8.249436e-13  1.336026e-12  2.078939e-09
#
#       svd_v_d_6
# 0  4.160009e-14
# 1  2.334478e-21
# 2  1.016047e-13
# 3  5.139933e-14
# 4  7.827372e-16

# %%
np.dot(df_source_u.values,df_destination_u.values.T) # Showing Memory Error so we have to do it row by row
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-e3592bbe86d5> in <module>()
# ----> 1 np.dot(df_source_u.values,df_destination_u.values.T) # Showing Memory Error so we have to do it row by row
#
# MemoryError:

# %%
df_source_u.shape
# Out:
# (100002, 6)

# %%
from tqdm import tqdm
svd_dot_u=[]
for i in tqdm(range(100002)):
    source=[]
    destination=[]
    for j in range(6):
        source.append(df_source_u.iloc[i][j])
        destination.append(df_destination_u.iloc[i][j])
    svd_dot_u.append(np.dot(source,destination))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 100002/100002 [02:15<00:00, 735.40it/s]

# %%
df_final_train['SVD_Dot_U']=svd_dot_u

# %%
from tqdm import tqdm
svd_dot_v=[]
for i in tqdm(range(100002)):
    source=[]
    destination=[]
    for j in range(6):
        source.append(df_source_v.iloc[i][j])
        destination.append(df_destination_v.iloc[i][j])
    svd_dot_v.append(np.dot(source,destination))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 100002/100002 [02:00<00:00, 828.86it/s]

# %%
df_final_train['SVD_Dot_V']=svd_dot_v

# %%
df_source_test_u=df_final_test[['svd_u_s_1', 'svd_u_s_2', 'svd_u_s_3', 'svd_u_s_4', 'svd_u_s_5',
       'svd_u_s_6']]
df_source_test_v=df_final_test[['svd_v_s_1', 'svd_v_s_2', 'svd_v_s_3',
       'svd_v_s_4', 'svd_v_s_5', 'svd_v_s_6']]

df_destination_test_u=df_final_test[['svd_u_d_1', 'svd_u_d_2', 'svd_u_d_3', 'svd_u_d_4',
       'svd_u_d_5', 'svd_u_d_6']]
df_destination_test_v=df_final_test[['svd_v_d_1', 'svd_v_d_2',
       'svd_v_d_3', 'svd_v_d_4', 'svd_v_d_5', 'svd_v_d_6']]

# %%
df_source_test_u.shape
# Out:
# (50002, 6)

# %%
from tqdm import tqdm
svd_dot_u=[]
for i in tqdm(range(50002)):
    source=[]
    destination=[]
    for j in range(6):
        source.append(df_source_test_u.iloc[i][j])
        destination.append(df_destination_test_u.iloc[i][j])
    svd_dot_u.append(np.dot(source,destination))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 50002/50002 [01:01<00:00, 818.34it/s]

# %%
df_final_test['SVD_Dot_U']=svd_dot_u

# %%
from tqdm import tqdm
svd_dot_v=[]
for i in tqdm(range(50002)):
    source=[]
    destination=[]
    for j in range(6):
        source.append(df_source_test_v.iloc[i][j])
        destination.append(df_destination_test_v.iloc[i][j])
    svd_dot_v.append(np.dot(source,destination))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 50002/50002 [01:01<00:00, 810.88it/s]

# %%
df_final_test['SVD_Dot_V']=svd_dot_v

# %%
df_final_train.head()
# Out:
#    jaccard_followers  jaccard_followees  cosine_followers  cosine_followees  \
# 0                  0           0.000000          0.000000          0.000000
# 1                  0           0.407407          0.169548          0.582182
# 2                  0           0.187500          0.134164          0.327327
# 3                  0           0.000000          0.000000          0.000000
# 4                  0           0.000000          0.050252          0.000000
#
#    num_followers_s  num_followers_d  num_followees_s  num_followees_d  \
# 0               11                6               15                8
# 1               29               23               21               17
# 2                5               10                7               12
# 3                8               13               15               24
# 4               11                6               12                6
#
#    inter_followers  inter_followees      ...          svd_v_s_5     svd_v_s_6  \
# 0                0                0      ...       8.108427e-13  1.719701e-14
# 1               21               11      ...      -1.603849e-19  5.689671e-21
# 2                3                3      ...       2.528174e-14  4.889795e-14
# 3                0                0      ...       1.788353e-12  1.488907e-15
# 4                1                0      ...       2.353031e-09  5.623551e-15
#
#       svd_v_d_1     svd_v_d_2     svd_v_d_3     svd_v_d_4     svd_v_d_5  \
# 0 -1.355366e-12  4.675306e-13  1.128588e-06  6.616654e-14  9.771068e-13
# 1  1.274447e-19 -6.288189e-20  5.755000e-20 -2.025439e-19 -1.265326e-19
# 2 -1.195007e-12  3.169914e-13  9.242597e-11  1.221675e-12  2.639144e-11
# 3 -1.645821e-12  1.690582e-11  1.947851e-10  7.582002e-12  1.077090e-11
# 4 -5.094863e-13  6.828593e-13  8.249436e-13  1.336026e-12  2.078939e-09
#
#       svd_v_d_6     SVD_Dot_U     SVD_Dot_V
# 0  4.160009e-14  1.114954e-11  2.238786e-12
# 1  2.334478e-21  1.838989e-36  9.818655e-38
# 2  1.016047e-13  5.426744e-20  3.687745e-21
# 3  5.139933e-14  9.660288e-19  6.748798e-20
# 4  7.827372e-16  8.538668e-22  4.891822e-18
#
# [5 rows x 54 columns]

# %%
df_final_test.head()
# Out:
#    jaccard_followers  jaccard_followees  cosine_followers  cosine_followees  \
# 0                  0           0.000000          0.029161          0.000000
# 1                  0           0.125000          0.106600          0.321288
# 2                  0           0.000000          0.000000          0.000000
# 3                  0           0.045455          0.057378          0.087039
# 4                  0           0.500000          0.353553          0.707107
#
#    num_followers_s  num_followers_d  num_followees_s  num_followees_d  \
# 0                6               14                6                9
# 1               22                2               31                5
# 2               15                7               14                8
# 3               15                9               12               11
# 4                2                4                2                1
#
#    inter_followers  inter_followees      ...          svd_v_s_5     svd_v_s_6  \
# 0                1                0      ...       4.341619e-13  5.535503e-14
# 1                1                4      ...       2.112207e-11  3.098817e-14
# 2                0                0      ...       2.009009e-13  4.980849e-16
# 3                2                1      ...       5.538798e-10  2.562606e-14
# 4                2                1      ...       2.608046e-15  7.724837e-20
#
#       svd_v_d_1     svd_v_d_2     svd_v_d_3     svd_v_d_4     svd_v_d_5  \
# 0 -9.994074e-10  5.791914e-10  3.512362e-07  2.486660e-09  2.771146e-09
# 1 -9.541405e-14  2.107418e-13  2.150839e-11  9.343828e-14  2.076078e-11
# 2 -6.912220e-15  1.304667e-13  1.316441e-12  2.169130e-14  1.832262e-13
# 3 -3.016805e-12  1.931616e-11  1.092595e-11  6.573112e-12  2.253590e-11
# 4 -1.008605e-18  3.583089e-16  2.716545e-15  3.196035e-17  2.608390e-15
#
#       svd_v_d_6     SVD_Dot_U     SVD_Dot_V
# 0  1.727695e-12  8.425017e-20  2.074816e-17
# 1  2.548702e-14  5.693283e-21  1.432277e-21
# 2  4.897869e-16  6.843556e-22  7.817469e-23
# 3  2.592157e-12  7.193543e-20  4.909734e-20
# 4  7.746406e-20  6.158387e-32  1.430929e-29
#
# [5 rows x 54 columns]

# %% [markdown]
# # Applying XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid = {'silent': [False],
        'max_depth': [6, 10, 15, 20],      
        'colsample_bytree': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bylevel': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'gamma': [0, 0.25, 0.5, 1.0],
        'n_estimators': [100,120,150,160]}

# %%
model = RandomizedSearchCV(XGBClassifier(), param_distributions=param_grid,
                                   n_iter=5,cv=3,scoring='f1')

# %%
model.fit(df_final_train,y_train)
# Out:
# [02:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1026 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2156 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2192 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2786 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1366 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1460 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1634 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2596 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1694 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1108 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1318 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1302 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2076 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1178 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2038 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2076 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1748 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1718 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1854 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1584 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1684 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1378 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1686 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1200 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1026 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1130 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1346 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1046 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1258 extra nodes, 0 pruned nodes, max_depth=20
# [02:12:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1404 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1038 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1186 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1734 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 580 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1122 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 680 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1076 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1004 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1178 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 906 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1026 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 860 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 626 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 742 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 686 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 602 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 928 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 854 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 842 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 620 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 726 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 646 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 642 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 728 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 854 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 756 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 614 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 758 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 700 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 716 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 736 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 664 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 582 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 624 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 666 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 594 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 560 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 556 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 516 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 542 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 522 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 556 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 504 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 0 pruned nodes, max_depth=15
# [02:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 0 pruned nodes, max_depth=15
# [02:13:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 0 pruned nodes, max_depth=15
# [02:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 0 pruned nodes, max_depth=14
# [02:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 0 pruned nodes, max_depth=14
# [02:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 0 pruned nodes, max_depth=14
# [02:13:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 0 pruned nodes, max_depth=15
# [02:13:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=14
# [02:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 0 pruned nodes, max_depth=15
# [02:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=15
# [02:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 906 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2478 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2164 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2840 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1560 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1452 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1464 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2588 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1818 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1206 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1600 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1468 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2166 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1320 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2272 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2186 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1898 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1678 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1808 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1630 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1744 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1382 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1684 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1208 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1356 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1050 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1374 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 946 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1246 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1372 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1028 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1140 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1848 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 640 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1052 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 746 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1248 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1002 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1120 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1064 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 942 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 852 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 702 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 838 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 724 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 660 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 992 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 554 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 816 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 794 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 830 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 834 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 554 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 708 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 860 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 578 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 648 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 754 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 664 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 670 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 638 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 608 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 632 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 566 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 562 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 614 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 552 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 0 pruned nodes, max_depth=17
# [02:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 0 pruned nodes, max_depth=15
# [02:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 0 pruned nodes, max_depth=18
# [02:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 0 pruned nodes, max_depth=20
# [02:13:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 0 pruned nodes, max_depth=19
# [02:13:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 0 pruned nodes, max_depth=15
# [02:13:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 0 pruned nodes, max_depth=16
# [02:13:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 0 pruned nodes, max_depth=16
# [02:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 0 pruned nodes, max_depth=16
# [02:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 0 pruned nodes, max_depth=16
# [02:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 0 pruned nodes, max_depth=16
# [02:14:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 0 pruned nodes, max_depth=17
# [02:14:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 0 pruned nodes, max_depth=18
# [02:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=18
# [02:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 0 pruned nodes, max_depth=16
# [02:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 0 pruned nodes, max_depth=17
# [02:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=18
# [02:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 0 pruned nodes, max_depth=18
# [02:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 0 pruned nodes, max_depth=15
# [02:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 0 pruned nodes, max_depth=15
# [02:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 0 pruned nodes, max_depth=15
# [02:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 0 pruned nodes, max_depth=14
# [02:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 0 pruned nodes, max_depth=17
# [02:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 0 pruned nodes, max_depth=16
# [02:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=18
# [02:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1010 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2366 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2156 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2626 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1404 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1410 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1530 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2548 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1790 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1208 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1464 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1326 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2004 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1320 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2040 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2078 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1740 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1764 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1568 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1486 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1658 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1238 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1680 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1238 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1056 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1204 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1312 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 924 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1266 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1400 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1104 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1068 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1782 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 608 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1102 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 594 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1266 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 992 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1144 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1120 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 792 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 838 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 660 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 854 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 716 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 778 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 914 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 892 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 838 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 680 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 846 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 606 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 664 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 692 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 576 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 666 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 746 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 708 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 634 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 692 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 552 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 600 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 624 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 512 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 578 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 550 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 0 pruned nodes, max_depth=16
# [02:14:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 630 extra nodes, 0 pruned nodes, max_depth=19
# [02:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 624 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 0 pruned nodes, max_depth=18
# [02:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 0 pruned nodes, max_depth=18
# [02:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 542 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 0 pruned nodes, max_depth=18
# [02:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 0 pruned nodes, max_depth=16
# [02:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 428 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 0 pruned nodes, max_depth=20
# [02:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 0 pruned nodes, max_depth=17
# [02:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 0 pruned nodes, max_depth=20
# ...
# [02:21:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 8 pruned nodes, max_depth=10
# [02:21:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 32 pruned nodes, max_depth=10
# [02:21:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 20 pruned nodes, max_depth=10
# [02:21:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 16 pruned nodes, max_depth=10
# [02:21:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 18 pruned nodes, max_depth=10
# [02:21:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 6 pruned nodes, max_depth=10
# [02:21:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 10 pruned nodes, max_depth=10
# [02:21:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 14 pruned nodes, max_depth=10
# [02:21:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 6 pruned nodes, max_depth=10
# [02:21:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 16 pruned nodes, max_depth=10
# [02:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2 pruned nodes, max_depth=10
# [02:21:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=10
# [02:21:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 14 pruned nodes, max_depth=10
# [02:21:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 6 pruned nodes, max_depth=10
# [02:21:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 14 pruned nodes, max_depth=10
# [02:21:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 10 pruned nodes, max_depth=10
# [02:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 6 pruned nodes, max_depth=10
# [02:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 14 pruned nodes, max_depth=10
# [02:21:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=10
# [02:21:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 8 pruned nodes, max_depth=10
# [02:21:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 6 pruned nodes, max_depth=10
# [02:21:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 10 pruned nodes, max_depth=10
# [02:21:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 10 pruned nodes, max_depth=10
# [02:21:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 22 pruned nodes, max_depth=10
# [02:21:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 10 pruned nodes, max_depth=10
# [02:21:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=10
# [02:21:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 8 pruned nodes, max_depth=10
# [02:21:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 2 pruned nodes, max_depth=10
# [02:21:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 24 pruned nodes, max_depth=10
# [02:21:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 16 pruned nodes, max_depth=10
# [02:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 30 pruned nodes, max_depth=10
# [02:21:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 16 pruned nodes, max_depth=10
# [02:21:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 10 pruned nodes, max_depth=10
# [02:21:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 22 pruned nodes, max_depth=10
# [02:21:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 8 pruned nodes, max_depth=10
# [02:21:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 6 pruned nodes, max_depth=10
# [02:21:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 14 pruned nodes, max_depth=10
# [02:21:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 16 pruned nodes, max_depth=10
# [02:21:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 18 pruned nodes, max_depth=10
# [02:21:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 12 pruned nodes, max_depth=10
# [02:21:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 18 pruned nodes, max_depth=10
# [02:21:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 14 pruned nodes, max_depth=10
# [02:21:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 20 pruned nodes, max_depth=10
# [02:21:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 32 pruned nodes, max_depth=10
# [02:21:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 24 pruned nodes, max_depth=10
# [02:21:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 28 pruned nodes, max_depth=10
# [02:22:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 26 pruned nodes, max_depth=10
# [02:22:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 22 pruned nodes, max_depth=10
# [02:22:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 18 pruned nodes, max_depth=10
# [02:22:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 36 pruned nodes, max_depth=10
# [02:22:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 60 pruned nodes, max_depth=10
# [02:22:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 52 pruned nodes, max_depth=10
# [02:22:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 34 pruned nodes, max_depth=10
# [02:22:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 26 pruned nodes, max_depth=10
# [02:22:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 38 pruned nodes, max_depth=10
# [02:22:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 36 pruned nodes, max_depth=10
# [02:22:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 22 pruned nodes, max_depth=10
# [02:22:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 34 pruned nodes, max_depth=10
# [02:22:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 46 pruned nodes, max_depth=10
# [02:22:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 34 pruned nodes, max_depth=10
# [02:22:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 48 pruned nodes, max_depth=10
# [02:22:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 32 pruned nodes, max_depth=10
# [02:22:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 52 pruned nodes, max_depth=10
# [02:22:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 22 pruned nodes, max_depth=10
# [02:22:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 56 pruned nodes, max_depth=10
# [02:22:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 32 pruned nodes, max_depth=10
# [02:22:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 26 pruned nodes, max_depth=10
# [02:22:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 40 pruned nodes, max_depth=10
# [02:22:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 58 pruned nodes, max_depth=10
# [02:22:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=10
# [02:22:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 72 pruned nodes, max_depth=10
# [02:22:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 68 pruned nodes, max_depth=10
# [02:22:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 24 pruned nodes, max_depth=10
# [02:22:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=10
# [02:22:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 28 pruned nodes, max_depth=10
# [02:22:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 38 pruned nodes, max_depth=10
# [02:22:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 62 pruned nodes, max_depth=10
# [02:22:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 34 pruned nodes, max_depth=10
# [02:22:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 62 pruned nodes, max_depth=10
# [02:22:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 18 pruned nodes, max_depth=10
# [02:22:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 62 pruned nodes, max_depth=10
# [02:22:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 24 pruned nodes, max_depth=10
# [02:22:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 42 pruned nodes, max_depth=10
# [02:22:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 60 pruned nodes, max_depth=10
# [02:22:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 44 pruned nodes, max_depth=10
# [02:22:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 30 pruned nodes, max_depth=10
# [02:22:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 62 pruned nodes, max_depth=10
# [02:22:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 20 pruned nodes, max_depth=10
# [02:22:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 56 pruned nodes, max_depth=10
# [02:22:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 60 pruned nodes, max_depth=10
# [02:22:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 56 pruned nodes, max_depth=10
# [02:22:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 20 pruned nodes, max_depth=10
# [02:22:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 16 pruned nodes, max_depth=10
# [02:22:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 48 pruned nodes, max_depth=10
# [02:22:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 20 pruned nodes, max_depth=10
# [02:22:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 50 pruned nodes, max_depth=10
# [02:22:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 56 pruned nodes, max_depth=10
# [02:22:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 76 pruned nodes, max_depth=10
# [02:22:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 46 pruned nodes, max_depth=10
# [02:22:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 66 pruned nodes, max_depth=10
# [02:22:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 72 pruned nodes, max_depth=10
# [02:22:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 66 pruned nodes, max_depth=10
# [02:22:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 54 pruned nodes, max_depth=10
# [02:22:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 86 pruned nodes, max_depth=10
# [02:22:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 78 pruned nodes, max_depth=10
# [02:22:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 128 pruned nodes, max_depth=10
# [02:22:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=10
# [02:22:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 48 pruned nodes, max_depth=10
# [02:22:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 68 pruned nodes, max_depth=10
# [02:22:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 78 pruned nodes, max_depth=10
# [02:22:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 68 pruned nodes, max_depth=10
# [02:22:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 58 pruned nodes, max_depth=10
# [02:22:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 30 pruned nodes, max_depth=10
# [02:22:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 98 pruned nodes, max_depth=10
# [02:22:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 76 pruned nodes, max_depth=10
# [02:22:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 66 pruned nodes, max_depth=10
# [02:22:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 98 pruned nodes, max_depth=10
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bytree=1, gamma=0,
#                                            learning_rate=0.1, max_delta_step=0,
#                                            max_depth=3, min_child_weight=1,
#                                            missing=None, n_estimators=100,
#                                            n_jobs=1, nthread=None,
#                                            objective='binary:logistic',
#                                            random_state=0, reg_alpha=0,
#                                            reg_lambda=1, scale...
#                    iid='warn', n_iter=5, n_jobs=None,
#                    param_distributions={'colsample_bylevel': [0.4, 0.5, 0.6,
#                                                               0.7, 0.8, 0.9,
#                                                               1.0],
#                                         'colsample_bytree': [0.4, 0.5, 0.6, 0.7,
#                                                              0.8, 0.9, 1.0],
#                                         'gamma': [0, 0.25, 0.5, 1.0],
#                                         'max_depth': [6, 10, 15, 20],
#                                         'n_estimators': [100, 120, 150, 160],
#                                         'silent': [False]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='f1', verbose=0)

# %%
print(model.best_estimator_)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=0.8,
#               colsample_bytree=0.9, gamma=1.0, learning_rate=0.1,
#               max_delta_step=0, max_depth=10, min_child_weight=1, missing=None,
#               n_estimators=150, n_jobs=1, nthread=None,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=False,
#               subsample=1)

# %%
clf=model.best_estimator_

# %%
clf.fit(df_final_train,y_train)
y_train_pred = clf.predict(df_final_train)
y_test_pred = clf.predict(df_final_test)
# Out:
# [02:22:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 20 pruned nodes, max_depth=10
# [02:22:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 8 pruned nodes, max_depth=10
# [02:22:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 14 pruned nodes, max_depth=10
# [02:22:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 6 pruned nodes, max_depth=10
# [02:22:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 18 pruned nodes, max_depth=10
# [02:22:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 20 pruned nodes, max_depth=10
# [02:22:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 22 pruned nodes, max_depth=10
# [02:22:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 14 pruned nodes, max_depth=10
# [02:22:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 16 pruned nodes, max_depth=10
# [02:22:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 14 pruned nodes, max_depth=10
# [02:22:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 30 pruned nodes, max_depth=10
# [02:22:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 24 pruned nodes, max_depth=10
# [02:22:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 6 pruned nodes, max_depth=10
# [02:22:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 20 pruned nodes, max_depth=10
# [02:22:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 36 pruned nodes, max_depth=10
# [02:22:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 10 pruned nodes, max_depth=10
# [02:22:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 26 pruned nodes, max_depth=10
# [02:22:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 16 pruned nodes, max_depth=10
# [02:22:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 18 pruned nodes, max_depth=10
# [02:22:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 14 pruned nodes, max_depth=10
# [02:22:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 24 pruned nodes, max_depth=10
# [02:22:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 10 pruned nodes, max_depth=10
# [02:22:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 18 pruned nodes, max_depth=10
# [02:23:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 8 pruned nodes, max_depth=10
# [02:23:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 32 pruned nodes, max_depth=10
# [02:23:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 20 pruned nodes, max_depth=10
# [02:23:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 16 pruned nodes, max_depth=10
# [02:23:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 18 pruned nodes, max_depth=10
# [02:23:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 6 pruned nodes, max_depth=10
# [02:23:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 10 pruned nodes, max_depth=10
# [02:23:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 6 pruned nodes, max_depth=10
# [02:23:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 16 pruned nodes, max_depth=10
# [02:23:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2 pruned nodes, max_depth=10
# [02:23:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=10
# [02:23:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 6 pruned nodes, max_depth=10
# [02:23:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 10 pruned nodes, max_depth=10
# [02:23:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 6 pruned nodes, max_depth=10
# [02:23:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=10
# [02:23:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 8 pruned nodes, max_depth=10
# [02:23:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 6 pruned nodes, max_depth=10
# [02:23:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 10 pruned nodes, max_depth=10
# [02:23:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 10 pruned nodes, max_depth=10
# [02:23:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 22 pruned nodes, max_depth=10
# [02:23:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 10 pruned nodes, max_depth=10
# [02:23:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=10
# [02:23:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 8 pruned nodes, max_depth=10
# [02:23:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 2 pruned nodes, max_depth=10
# [02:23:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 24 pruned nodes, max_depth=10
# [02:23:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 16 pruned nodes, max_depth=10
# [02:23:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 30 pruned nodes, max_depth=10
# [02:23:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 16 pruned nodes, max_depth=10
# [02:23:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 10 pruned nodes, max_depth=10
# [02:23:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 22 pruned nodes, max_depth=10
# [02:23:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 8 pruned nodes, max_depth=10
# [02:23:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 6 pruned nodes, max_depth=10
# [02:23:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 16 pruned nodes, max_depth=10
# [02:23:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 18 pruned nodes, max_depth=10
# [02:23:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 18 pruned nodes, max_depth=10
# [02:23:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 20 pruned nodes, max_depth=10
# [02:23:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 32 pruned nodes, max_depth=10
# [02:23:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 24 pruned nodes, max_depth=10
# [02:23:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 28 pruned nodes, max_depth=10
# [02:23:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 26 pruned nodes, max_depth=10
# [02:23:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 22 pruned nodes, max_depth=10
# [02:23:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 18 pruned nodes, max_depth=10
# [02:23:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 36 pruned nodes, max_depth=10
# [02:23:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 60 pruned nodes, max_depth=10
# [02:23:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 52 pruned nodes, max_depth=10
# [02:23:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 34 pruned nodes, max_depth=10
# [02:23:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 26 pruned nodes, max_depth=10
# [02:23:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 38 pruned nodes, max_depth=10
# [02:23:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 36 pruned nodes, max_depth=10
# [02:23:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 22 pruned nodes, max_depth=10
# [02:23:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 34 pruned nodes, max_depth=10
# [02:23:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 46 pruned nodes, max_depth=10
# [02:23:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 34 pruned nodes, max_depth=10
# [02:23:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 48 pruned nodes, max_depth=10
# [02:23:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 32 pruned nodes, max_depth=10
# [02:23:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 52 pruned nodes, max_depth=10
# [02:23:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 22 pruned nodes, max_depth=10
# [02:23:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 56 pruned nodes, max_depth=10
# [02:23:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 32 pruned nodes, max_depth=10
# [02:23:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 26 pruned nodes, max_depth=10
# [02:23:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 40 pruned nodes, max_depth=10
# [02:23:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 58 pruned nodes, max_depth=10
# [02:23:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=10
# [02:23:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 72 pruned nodes, max_depth=10
# [02:23:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 68 pruned nodes, max_depth=10
# [02:23:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 24 pruned nodes, max_depth=10
# [02:23:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=10
# [02:23:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 28 pruned nodes, max_depth=10
# [02:23:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 38 pruned nodes, max_depth=10
# [02:23:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 62 pruned nodes, max_depth=10
# [02:23:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 34 pruned nodes, max_depth=10
# [02:23:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 62 pruned nodes, max_depth=10
# [02:23:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 18 pruned nodes, max_depth=10
# [02:23:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 62 pruned nodes, max_depth=10
# [02:23:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 24 pruned nodes, max_depth=10
# [02:23:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 42 pruned nodes, max_depth=10
# [02:23:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 60 pruned nodes, max_depth=10
# [02:23:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 44 pruned nodes, max_depth=10
# [02:23:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 30 pruned nodes, max_depth=10
# [02:24:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 62 pruned nodes, max_depth=10
# [02:24:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 20 pruned nodes, max_depth=10
# [02:24:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 56 pruned nodes, max_depth=10
# [02:24:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 60 pruned nodes, max_depth=10
# [02:24:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 56 pruned nodes, max_depth=10
# [02:24:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 20 pruned nodes, max_depth=10
# [02:24:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 16 pruned nodes, max_depth=10
# [02:24:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 48 pruned nodes, max_depth=10
# [02:24:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 20 pruned nodes, max_depth=10
# [02:24:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 50 pruned nodes, max_depth=10
# [02:24:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 56 pruned nodes, max_depth=10
# [02:24:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 76 pruned nodes, max_depth=10
# [02:24:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 46 pruned nodes, max_depth=10
# [02:24:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 66 pruned nodes, max_depth=10
# [02:24:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 72 pruned nodes, max_depth=10
# [02:24:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 66 pruned nodes, max_depth=10
# [02:24:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 54 pruned nodes, max_depth=10
# [02:24:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 86 pruned nodes, max_depth=10
# [02:24:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 78 pruned nodes, max_depth=10
# [02:24:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 128 pruned nodes, max_depth=10
# [02:24:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 18 pruned nodes, max_depth=10
# [02:24:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 48 pruned nodes, max_depth=10
# [02:24:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 68 pruned nodes, max_depth=10
# [02:24:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 78 pruned nodes, max_depth=10
# [02:24:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 68 pruned nodes, max_depth=10
# [02:24:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 58 pruned nodes, max_depth=10
# [02:24:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 30 pruned nodes, max_depth=10
# [02:24:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 98 pruned nodes, max_depth=10
# [02:24:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 76 pruned nodes, max_depth=10
# [02:24:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 66 pruned nodes, max_depth=10
# [02:24:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 98 pruned nodes, max_depth=10

# %%
from sklearn.metrics import f1_score
print('Train f1 score',f1_score(y_train,y_train_pred))
print('Test f1 score',f1_score(y_test,y_test_pred))
# Out:
# Train f1 score 0.996942202617
# Test f1 score 0.930134056206

# %%
print('Train confusion_matrix')
plot_confusion_matrix(y_train,y_train_pred)
print('Test confusion_matrix')
plot_confusion_matrix(y_test,y_test_pred)
# Out:
# Train confusion_matrix
# Test confusion_matrix

# %%
from sklearn.metrics import roc_curve, auc
fpr,tpr,ths = roc_curve(y_test,y_test_pred)
auc_sc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='navy',label='ROC curve (area = %0.2f)' % auc_sc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic with test data')
plt.legend()
plt.show()

# %%
features = df_final_train.columns
importances = clf.feature_importances_
indices = (np.argsort(importances))[-25:]
plt.figure(figsize=(10,12))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='r', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
from prettytable import PrettyTable
x = PrettyTable()
x.field_names = [ "Model","max_depth",'n_estimators','Training_F1_Score','Testing_F1_Score']

# %%
x.add_row(['Random_Forest',14,121,0.966,0.928])
x.add_row(['XG_Boost',10,150,0.996,0.930])

# %%
print(x)
# Out:
# +---------------+-----------+--------------+-------------------+------------------+
# |     Model     | max_depth | n_estimators | Training_F1_Score | Testing_F1_Score |
# +---------------+-----------+--------------+-------------------+------------------+
# | Random_Forest |     14    |     121      |       0.966       |      0.928       |
# |    XG_Boost   |     10    |     150      |       0.996       |       0.93       |
# +---------------+-----------+--------------+-------------------+------------------+

# %% [markdown]
# # Conclusion

# %% [markdown]
# * Firstly we posed this dataset as classification problem by creating labels as 1 and 0
# * As the data was given in the form of nodes source and destination so we created some new features like jaccard distance,adar index ,page rank etc
# * Then we trained our model using Random Forest with best hyper parameters and got the training f1_score 0.966 and testing f1 score 0.928 which is good as it is not overfitting nor underfitting
# * we also trained our model using XG Boost from which we got training f1 score .930 and testing score .929 which shows some overfitting as training f1 score is nearly 1
# * Some of the best features are page rank,follows back,shortest path
